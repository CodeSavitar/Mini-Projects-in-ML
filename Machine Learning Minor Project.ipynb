# %%
#Project done by: Adhith Sankar

# %%
#Importing the required libraries

import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r'C:\Users\Aadhi\StudentsPerformance.csv')
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data.shape
# Out:
# (1000, 16)

# %%
#Checking for missing values

data.isnull()
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0     False           False                        False  False
# 1     False           False                        False  False
# 2     False           False                        False  False
# 3     False           False                        False  False
# 4     False           False                        False  False
# ..      ...             ...                          ...    ...
# 995   False           False                        False  False
# 996   False           False                        False  False
# 997   False           False                        False  False
# 998   False           False                        False  False
# 999   False           False                        False  False
#
#      test preparation course  math score  reading score  writing score
# 0                      False       False          False          False
# ...

# %%
#There are no missing values
#Checking data types

data.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
#Counting repeated data

data['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
data['race/ethnicity'].value_counts()
# Out:
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: race/ethnicity, dtype: int64

# %%
data['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
data['lunch'].value_counts()
# Out:
# standard        645
# free/reduced    355
# Name: lunch, dtype: int64

# %%
data['test preparation course'].value_counts()
# Out:
# none         642
# completed    358
# Name: test preparation course, dtype: int64

# %%
#Getting the total and average scores

data['total']=data['math score']+data['reading score']+data['writing score']
data['average']=data['total']/3

# %%
#Analysing the distribution of the scores

sns.distplot(data['math score'])

# %%
sns.distplot(data['reading score'])

# %%
sns.distplot(data['writing score'])

# %%
sns.distplot(data['average'])

# %%
sns.barplot(data['gender'],data['average'])

# %%
sns.barplot(data['race/ethnicity'],data['average'])

# %%
sns.barplot(data['parental level of education'],data['average'])

# %%
sns.barplot(data['test preparation course'],data['average'])

# %%
sns.barplot(data['lunch'],data['average'])

# %%
#Analysing the no. of students who passed the exam

data['math_status']=np.where(data['math score']<40,'F','P')
data['read_status']=np.where(data['reading score']<40,'F','P')
data['write_status']=np.where(data['writing score']<40,'F','P')

# %%
data['math_status'].value_counts()
# Out:
# P    960
# F     40
# Name: math_status, dtype: int64

# %%
data['read_status'].value_counts()
# Out:
# P    974
# F     26
# Name: read_status, dtype: int64

# %%
data['write_status'].value_counts()
# Out:
# P    968
# F     32
# Name: write_status, dtype: int64

# %%
#Plotting the analysed data

sns.set(style="darkgrid")
p=sns.countplot(x='gender',data=data,hue='math_status',palette='dark')
_=plt.setp(p.get_xticklabels(),rotation=90)

# %%
p=sns.countplot(x='gender',data=data,hue='read_status',palette='dark')
_=plt.setp(p.get_xticklabels(),rotation=90)

# %%
p=sns.countplot(x='gender',data=data,hue='write_status',palette='dark')
_=plt.setp(p.get_xticklabels(),rotation=90)

# %%
p=sns.countplot(x='race/ethnicity',data=data,hue='math_status',palette='dark')
_=plt.setp(p.get_xticklabels(),rotation=90)

# %%
p=sns.countplot(x='race/ethnicity',data=data,hue='read_status',palette='dark')
_=plt.setp(p.get_xticklabels(),rotation=90)

# %%
p=sns.countplot(x='race/ethnicity',data=data,hue='write_status',palette='dark')
_=plt.setp(p.get_xticklabels(),rotation=90)

# %%
p=sns.countplot(x='parental level of education',data=data,hue='math_status',palette='dark')
_=plt.setp(p.get_xticklabels(),rotation=90)

# %%
p=sns.countplot(x='parental level of education',data=data,hue='read_status',palette='dark')
_=plt.setp(p.get_xticklabels(),rotation=90)

# %%
p=sns.countplot(x='parental level of education',data=data,hue='write_status',palette='dark')
_=plt.setp(p.get_xticklabels(),rotation=90)

# %%
p=sns.countplot(x='lunch',data=data,hue='math_status',palette='dark')
_=plt.setp(p.get_xticklabels(),rotation=90)

# %%
p=sns.countplot(x='lunch',data=data,hue='read_status',palette='dark')
_=plt.setp(p.get_xticklabels(),rotation=90)

# %%
p=sns.countplot(x='lunch',data=data,hue='write_status',palette='dark')
_=plt.setp(p.get_xticklabels(),rotation=90)

# %%
p=sns.countplot(x='test preparation course',data=data,hue='math_status',palette='dark')
_=plt.setp(p.get_xticklabels(),rotation=90)

# %%
p=sns.countplot(x='test preparation course',data=data,hue='read_status',palette='dark')
_=plt.setp(p.get_xticklabels(),rotation=90)

# %%
p=sns.countplot(x='test preparation course',data=data,hue='write_status',palette='dark')
_=plt.setp(p.get_xticklabels(),rotation=90)
